# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# The purpose of this project is to analyze a csv file called insurance.csv, in order to have clear information about the cost of insurance in the United States according to several criteria represented in our csv file.To complete the project, I will use the skills I have learned in previous classes.

# %%
# We will mainly use the python library pandas for data analysis.
#importation of pandas' module
import pandas as pd

# %% [markdown]
# ## Recovery of data.

# %%
#read_csv allows us to read a csv file with pandas
insurance_cost_data = pd.read_csv('insurance.csv')

# %% [markdown]
# ## Examine data structure

# %% [markdown]
# Let's look at the first 50 lines using the head() method of the DataFrame

# %%
insurance_cost_data.head(50)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %% [markdown]
# Every line represents an observation our dataset.

# %%
insurance_cost_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# The info() method allows to obtain a description of the data, in particular
# the total number of rows, the type of each variable and the number of non
# null values

# %% [markdown]
# ### We have three categorical variables in our dataset: sex, smoker, and region.

# %% [markdown]
# We can obtain the list of the modalities
# of these categorical variables as well as the counts of each of them (i.e. the variables sex, smoker and region
# in each category) by using the value_counts() method:

# %%
print(f"Sex :\n {insurance_cost_data['sex'].value_counts()}\n")
print(f"Smoker :\n {insurance_cost_data['smoker'].value_counts()}\n")
print(f"Region :\n {insurance_cost_data['region'].value_counts()}\n")
# Out:
# Sex :
#  male      676
# female    662
# Name: sex, dtype: int64
#
# Smoker :
#  no     1064
# yes     274
# Name: smoker, dtype: int64
#
# Region :
#  southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# Let's look at the other fields: they are all quantitative variables or
# variables. The method describe()presents a summary of the numerical variables

# %%
insurance_cost_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# The lines count, mean, min and max provide the number of values, the mean, the minimum and the maximum respectively.
# values, the average, the minimum and the maximum respectively.
# The std line indicates the standard deviation (which
# the dispersion of the data)26. The lines 25%, 50% and 75% show the corresponding
# percentiles: a percentile indicates the value below which a given percentage of the observations in the group falls.
# percentage of the observations in the group.
# Per example mean's age of patients is 39.207025, and patients have in mean 1.094918 child.

# %% [markdown]
# ### Analyze the origin of the majority of the individuals.

# %%
insurance_cost_data.groupby(['region']).mean()
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377
